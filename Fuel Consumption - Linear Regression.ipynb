# %% [markdown]
# # Importing data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fueleconomy_df = pd.read_csv('/Users/usripha/Desktop/DataScience/FuelEconomy.csv')

# %%
fueleconomy_df.head()
# Out:
#    Horse Power  Fuel Economy (MPG)
# 0   118.770799           29.344195
# 1   176.326567           24.695934
# 2   219.262465           23.952010
# 3   187.310009           23.384546
# 4   218.594340           23.426739

# %%
#take a look at the number of instances in the dataset
fueleconomy_df.shape
# Out:
# (100, 2)

# %%
#understand the minimum, mean and if constant=0 
fueleconomy_df.describe()
# Out:
#        Horse Power  Fuel Economy (MPG)
# count   100.000000          100.000000
# mean    213.676190           23.178501
# std      62.061726            4.701666
# min      50.000000           10.000000
# 25%     174.996514           20.439516
# 50%     218.928402           23.143192
# 75%     251.706476           26.089933
# max     350.000000           35.000000

# %%
# we need to find out if the dataset has null values to clean up the data 
fueleconomy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
# Horse Power           100 non-null float64
# Fuel Economy (MPG)    100 non-null float64
# dtypes: float64(2)
# memory usage: 1.6 KB

# %% [markdown]
# # VISUALIZE DATASET

# %%
#plot the 2 features to check if they are linearly increasing or decreasing with respect to each other 
sns.jointplot(x = 'Horse Power', y = 'Fuel Economy (MPG)', data = fueleconomy_df)

# %%
sns.jointplot(x = 'Fuel Economy (MPG)', y = 'Horse Power', data = fueleconomy_df)

# %%
#indicates that they are inversly proportional so we need to expect to have a negative slope
#As horse power is increasing, fuel economy is decreasing. Same vice-versa

# %%
sns.pairplot(fueleconomy_df)

# %%
#shows the best fitting line
sns.lmplot(x = 'Horse Power', y =  'Fuel Economy (MPG)', data = fueleconomy_df)

# %%
sns.lmplot(x = 'Fuel Economy (MPG)', y =  'Horse Power', data = fueleconomy_df)

# %% [markdown]
# # CREATE TESTING AND TRAINING DATASET

# %%
X = fueleconomy_df[['Horse Power']]

# %%
y = fueleconomy_df['Fuel Economy (MPG)']

# %%
X.shape
# Out:
# (100, 1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
X_train.shape
# Out:
# (70, 1)

# %%
X_test.shape
# Out:
# (30, 1)

# %% [markdown]
# # TRAIN THE MODEL

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression(fit_intercept = True)
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
print('Linear Model Coeff (m)', regressor.coef_)
print('Linear Model Coeff (m)', regressor.intercept_)
# Out:
# Linear Model Coeff (m) [-0.06955947]
# Linear Model Coeff (m) 37.93876535335789

# %% [markdown]
# # TEST THE MODEL

# %%
y_predict = regressor.predict(X_test)

# %%
y_predict
# Out:
# array([17.70480699, 21.48296156, 23.6758196 , 20.98453289, 19.91012088,
#        19.05743199, 23.01933849, 25.92976442, 22.33365012, 24.24532072,
#        18.2809648 , 14.08639038, 29.67713198, 20.44981093, 20.94132945,
#        22.08800608, 25.69774478, 22.58553414, 17.10358658, 28.45736122,
#        24.99791914, 29.55794621, 28.63010467, 21.81106214, 14.86598815,
#        24.09933116, 22.73345976, 21.32542661, 23.77842972, 19.9709747 ])

# %%
y_test
# Out:
# 51    17.873266
# 16    23.185280
# 91    25.286954
# 42    21.442703
# 15    20.467374
# 6     17.163583
# 76    22.183092
# 41    27.387012
# 84    21.701202
# 46    24.355851
# 33    15.676316
# 89    10.000000
# 0     29.344195
# 56    22.965773
# 47    19.536770
# 36    23.488811
# 31    26.188478
# 62    23.059180
# 71    16.693369
# 19    31.497429
# 43    26.897067
# 11    29.678637
# 49    30.674803
# 27    24.829824
# 86    15.837968
# 80    23.172223
# 4     23.426739
# 85    19.674094
# 88    24.826199
# 74    21.261778
# Name: Fuel Economy (MPG), dtype: float64

# %%
plt.scatter(X_train, y_train, color='gray')
plt.plot(X_train, regressor.predict(X_train), color='blue')
plt.xlabel('Horse Power (HP)')
plt.ylabel('MPG')
plt.title('HP vs. MPG (Testing Set)')
# Out:
# Text(0.5, 1.0, 'HP vs. MPG (Testing Set)')

# %%
plt.scatter(X_test, y_test, color = 'gray')
plt.plot(X_test, regressor.predict(X_test), color = 'blue')
plt.xlabel('Horse Power (HP)')
plt.ylabel('MPG')
plt.title('HP vs. MPG (Testing Set)')
# Out:
# Text(0.5, 1.0, 'HP vs. MPG (Testing Set)')

# %%
HP = [500[]
# MPG?

# %%
MPG = regressor.predict(HP).reshape(-1, 1)
MPG
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-7e3375ca3619> in <module>
# ----> 1 MPG = regressor.predict(HP).reshape(-1, 1)
#       2 MPG
#
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/base.py in predict(self, X)
#     211             Returns predicted values.
#     212         """
# --> 213         return self._decision_function(X)
#     214
#     215     _preprocess_data = staticmethod(_preprocess_data)
#
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/base.py in _decision_function(self, X)
#     194         check_is_fitted(self, "coef_")
#     195
# --> 196         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     197         return safe_sparse_dot(X, self.coef_.T,
#     198                                dense_output=True) + self.intercept_
#
# ...
